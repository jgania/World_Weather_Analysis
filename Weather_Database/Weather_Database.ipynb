# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 745

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | eravur
# Processing Record 3 of Set 1 | belaya gora
# Processing Record 4 of Set 1 | cuamba
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | araouane
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | kashi
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | chernyshevskiy
# Processing Record 13 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 14 of Set 1 | tuatapere
# Processing Record 15 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 1 | comodoro rivadavia
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | san quintin
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | meulaboh
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | yomitan
# City not found. Skipping...
# Processing Record 27 of Set 1 | havre-saint-pierre
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | zhangye
# Processing Record 30 of Set 1 | leningradskiy
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | moirang
# Processing Record 34 of Set 1 | kununurra
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | florianopolis
# Processing Record 37 of Set 1 | urucara
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | rocha
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | sakakah
# Processing Record 46 of Set 1 | bonthe
# Processing Record 47 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 48 of Set 1 | pangnirtung
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | raudeberg
# Processing Record 1 of Set 2 | domodossola
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | shagonar
# Processing Record 4 of Set 2 | sitka
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | parrita
# Processing Record 7 of Set 2 | yakeshi
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | laguna
# Processing Record 12 of Set 2 | magadi
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | toamasina
# Processing Record 15 of Set 2 | coahuayana
# Processing Record 16 of Set 2 | sioux lookout
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | cedar city
# Processing Record 19 of Set 2 | rapid valley
# Processing Record 20 of Set 2 | hermosillo
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | tiznit
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | salalah
# Processing Record 25 of Set 2 | haines junction
# Processing Record 26 of Set 2 | toa alta
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | mozarlandia
# Processing Record 29 of Set 2 | floha
# Processing Record 30 of Set 2 | shelopugino
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | odienne
# Processing Record 33 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 2 | jardim
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | saint-alexandre
# Processing Record 39 of Set 2 | soe
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | dalbandin
# Processing Record 46 of Set 2 | isangel
# Processing Record 47 of Set 2 | dengfeng
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | los llanos de aridane
# Processing Record 50 of Set 2 | ketchikan
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | srednekolymsk
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | shache
# Processing Record 7 of Set 3 | narsaq
# Processing Record 8 of Set 3 | vastervik
# City not found. Skipping...
# Processing Record 9 of Set 3 | nalut
# Processing Record 10 of Set 3 | jati
# Processing Record 11 of Set 3 | hami
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | rio gallegos
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 3 | porto walter
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | bengkulu
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | broken hill
# Processing Record 21 of Set 3 | linkou
# Processing Record 22 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | constitucion
# Processing Record 24 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 3 | hella
# Processing Record 26 of Set 3 | kumbhraj
# Processing Record 27 of Set 3 | talara
# Processing Record 28 of Set 3 | kahului
# Processing Record 29 of Set 3 | tete
# Processing Record 30 of Set 3 | lodwar
# Processing Record 31 of Set 3 | necochea
# Processing Record 32 of Set 3 | ondjiva
# Processing Record 33 of Set 3 | mitsamiouli
# Processing Record 34 of Set 3 | beni suef
# Processing Record 35 of Set 3 | camacupa
# Processing Record 36 of Set 3 | khokholskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 3 | punta arenas
# Processing Record 40 of Set 3 | yulara
# Processing Record 41 of Set 3 | kuva
# City not found. Skipping...
# Processing Record 42 of Set 3 | salta
# Processing Record 43 of Set 3 | kupang
# Processing Record 44 of Set 3 | baruun-urt
# Processing Record 45 of Set 3 | tlapa
# City not found. Skipping...
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | margate
# Processing Record 48 of Set 3 | antofagasta
# Processing Record 49 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 3 | huarmey
# Processing Record 1 of Set 4 | obo
# Processing Record 2 of Set 4 | port elizabeth
# Processing Record 3 of Set 4 | jacareacanga
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | adrar
# Processing Record 6 of Set 4 | avarua
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | praia da vitoria
# Processing Record 9 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | port alfred
# Processing Record 12 of Set 4 | acarau
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | mercedes
# Processing Record 15 of Set 4 | yining
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | hofn
# Processing Record 18 of Set 4 | kautokeino
# Processing Record 19 of Set 4 | umm lajj
# Processing Record 20 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 21 of Set 4 | hambantota
# Processing Record 22 of Set 4 | tateyama
# Processing Record 23 of Set 4 | emerald
# Processing Record 24 of Set 4 | xinan
# Processing Record 25 of Set 4 | alofi
# Processing Record 26 of Set 4 | qaqortoq
# Processing Record 27 of Set 4 | altay
# Processing Record 28 of Set 4 | saint anthony
# Processing Record 29 of Set 4 | acapulco
# Processing Record 30 of Set 4 | kamenka
# Processing Record 31 of Set 4 | khani
# Processing Record 32 of Set 4 | price
# Processing Record 33 of Set 4 | phalaborwa
# Processing Record 34 of Set 4 | gasa
# Processing Record 35 of Set 4 | tera
# Processing Record 36 of Set 4 | port hardy
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | belmonte
# Processing Record 39 of Set 4 | vao
# Processing Record 40 of Set 4 | ust-uda
# Processing Record 41 of Set 4 | coihaique
# Processing Record 42 of Set 4 | bathsheba
# Processing Record 43 of Set 4 | fairbanks
# Processing Record 44 of Set 4 | xiongshi
# City not found. Skipping...
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | ampanihy
# Processing Record 47 of Set 4 | anar darreh
# City not found. Skipping...
# Processing Record 48 of Set 4 | port-gentil
# Processing Record 49 of Set 4 | lasa
# Processing Record 50 of Set 4 | blairmore
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | kropotkin
# Processing Record 4 of Set 5 | sandnessjoen
# Processing Record 5 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 5 | makakilo city
# Processing Record 7 of Set 5 | gusau
# Processing Record 8 of Set 5 | rorvik
# Processing Record 9 of Set 5 | katherine
# Processing Record 10 of Set 5 | aloleng
# Processing Record 11 of Set 5 | mittagong
# Processing Record 12 of Set 5 | sao filipe
# Processing Record 13 of Set 5 | tiarei
# Processing Record 14 of Set 5 | pevek
# Processing Record 15 of Set 5 | puerto ayora
# Processing Record 16 of Set 5 | tukrah
# Processing Record 17 of Set 5 | shahrud
# Processing Record 18 of Set 5 | panzhihua
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | kavieng
# Processing Record 21 of Set 5 | denpasar
# Processing Record 22 of Set 5 | blyth
# Processing Record 23 of Set 5 | san francisco
# Processing Record 24 of Set 5 | mabaruma
# Processing Record 25 of Set 5 | mahajanga
# Processing Record 26 of Set 5 | mineiros
# Processing Record 27 of Set 5 | le port
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | burica
# City not found. Skipping...
# Processing Record 30 of Set 5 | jiexiu
# Processing Record 31 of Set 5 | mayor pablo lagerenza
# Processing Record 32 of Set 5 | caravelas
# Processing Record 33 of Set 5 | kidal
# Processing Record 34 of Set 5 | barranca de upia
# Processing Record 35 of Set 5 | aklavik
# Processing Record 36 of Set 5 | grand gaube
# Processing Record 37 of Set 5 | mwinilunga
# Processing Record 38 of Set 5 | nanortalik
# Processing Record 39 of Set 5 | bosaso
# Processing Record 40 of Set 5 | puerto baquerizo moreno
# Processing Record 41 of Set 5 | barcelos
# Processing Record 42 of Set 5 | saint-pierre
# Processing Record 43 of Set 5 | namibe
# Processing Record 44 of Set 5 | mahanoro
# Processing Record 45 of Set 5 | itoman
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | sitamau
# Processing Record 48 of Set 5 | vilhena
# Processing Record 49 of Set 5 | barcelona
# Processing Record 50 of Set 5 | hithadhoo
# Processing Record 1 of Set 6 | winnemucca
# Processing Record 2 of Set 6 | kirakira
# Processing Record 3 of Set 6 | hualmay
# Processing Record 4 of Set 6 | kavaratti
# Processing Record 5 of Set 6 | nome
# Processing Record 6 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 6 | erzin
# Processing Record 8 of Set 6 | yar-sale
# Processing Record 9 of Set 6 | puerto quijarro
# Processing Record 10 of Set 6 | mar del plata
# Processing Record 11 of Set 6 | santa cruz del sur
# Processing Record 12 of Set 6 | lebu
# Processing Record 13 of Set 6 | cravo norte
# Processing Record 14 of Set 6 | dikson
# Processing Record 15 of Set 6 | verkhoyansk
# Processing Record 16 of Set 6 | port augusta
# Processing Record 17 of Set 6 | sinegorye
# Processing Record 18 of Set 6 | norman wells
# Processing Record 19 of Set 6 | viedma
# Processing Record 20 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 6 | lagoa
# Processing Record 22 of Set 6 | labuhan
# Processing Record 23 of Set 6 | isabela
# Processing Record 24 of Set 6 | teguise
# Processing Record 25 of Set 6 | baykit
# Processing Record 26 of Set 6 | rumphi
# Processing Record 27 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 28 of Set 6 | chokurdakh
# Processing Record 29 of Set 6 | athabasca
# Processing Record 30 of Set 6 | margherita
# Processing Record 31 of Set 6 | goulburn
# Processing Record 32 of Set 6 | ussuriysk
# Processing Record 33 of Set 6 | logansport
# Processing Record 34 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | sestri levante
# Processing Record 36 of Set 6 | sandwick
# Processing Record 37 of Set 6 | berlevag
# Processing Record 38 of Set 6 | bridlington
# Processing Record 39 of Set 6 | tautira
# Processing Record 40 of Set 6 | port lincoln
# Processing Record 41 of Set 6 | inhambane
# Processing Record 42 of Set 6 | vilyuysk
# Processing Record 43 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 6 | henties bay
# Processing Record 45 of Set 6 | qui nhon
# Processing Record 46 of Set 6 | georgetown
# Processing Record 47 of Set 6 | vanimo
# Processing Record 48 of Set 6 | ballina
# Processing Record 49 of Set 6 | kangaatsiaq
# Processing Record 50 of Set 6 | ivrea
# Processing Record 1 of Set 7 | jurado
# Processing Record 2 of Set 7 | vostok
# Processing Record 3 of Set 7 | moss point
# Processing Record 4 of Set 7 | ambon
# Processing Record 5 of Set 7 | lavrentiya
# Processing Record 6 of Set 7 | komsomolskiy
# Processing Record 7 of Set 7 | esperance
# Processing Record 8 of Set 7 | sinnamary
# Processing Record 9 of Set 7 | qarayeri
# Processing Record 10 of Set 7 | ayan
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | hamilton
# Processing Record 13 of Set 7 | cherrapunji
# Processing Record 14 of Set 7 | lensk
# Processing Record 15 of Set 7 | oum hadjer
# Processing Record 16 of Set 7 | klaksvik
# Processing Record 17 of Set 7 | katsuura
# Processing Record 18 of Set 7 | nuevitas
# Processing Record 19 of Set 7 | tumba
# Processing Record 20 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 7 | gamba
# Processing Record 22 of Set 7 | turukhansk
# Processing Record 23 of Set 7 | tocopilla
# Processing Record 24 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 7 | nenjiang
# Processing Record 26 of Set 7 | tonekabon
# Processing Record 27 of Set 7 | minusinsk
# Processing Record 28 of Set 7 | yumen
# Processing Record 29 of Set 7 | mandera
# Processing Record 30 of Set 7 | boguchany
# Processing Record 31 of Set 7 | kholmogory
# Processing Record 32 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 7 | upernavik
# Processing Record 34 of Set 7 | kourou
# Processing Record 35 of Set 7 | wanning
# Processing Record 36 of Set 7 | namatanai
# Processing Record 37 of Set 7 | itarema
# Processing Record 38 of Set 7 | marienburg
# Processing Record 39 of Set 7 | lufilufi
# Processing Record 40 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 7 | luderitz
# Processing Record 42 of Set 7 | saint-augustin
# Processing Record 43 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 44 of Set 7 | dong hoi
# Processing Record 45 of Set 7 | mackay
# Processing Record 46 of Set 7 | port blair
# Processing Record 47 of Set 7 | sumbe
# Processing Record 48 of Set 7 | mangai
# Processing Record 49 of Set 7 | ambilobe
# Processing Record 50 of Set 7 | cabo san lucas
# Processing Record 1 of Set 8 | lazaro cardenas
# Processing Record 2 of Set 8 | brookhaven
# Processing Record 3 of Set 8 | los chiles
# Processing Record 4 of Set 8 | north bend
# Processing Record 5 of Set 8 | zhoucheng
# Processing Record 6 of Set 8 | buala
# Processing Record 7 of Set 8 | bilma
# Processing Record 8 of Set 8 | moissala
# Processing Record 9 of Set 8 | abramovka
# Processing Record 10 of Set 8 | inirida
# Processing Record 11 of Set 8 | buzmeyin
# Processing Record 12 of Set 8 | almaznyy
# Processing Record 13 of Set 8 | kamina
# Processing Record 14 of Set 8 | greenwood
# Processing Record 15 of Set 8 | camana
# Processing Record 16 of Set 8 | roebourne
# Processing Record 17 of Set 8 | loikaw
# Processing Record 18 of Set 8 | gombong
# Processing Record 19 of Set 8 | weyburn
# Processing Record 20 of Set 8 | san vicente
# Processing Record 21 of Set 8 | las varas
# Processing Record 22 of Set 8 | sola
# Processing Record 23 of Set 8 | sawakin
# Processing Record 24 of Set 8 | stonewall
# Processing Record 25 of Set 8 | turinskaya sloboda
# Processing Record 26 of Set 8 | naze
# Processing Record 27 of Set 8 | bac lieu
# Processing Record 28 of Set 8 | tamazulapam
# City not found. Skipping...
# Processing Record 29 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 8 | olavarria
# Processing Record 31 of Set 8 | el alto
# Processing Record 32 of Set 8 | rosario
# Processing Record 33 of Set 8 | sistranda
# Processing Record 34 of Set 8 | atasu
# Processing Record 35 of Set 8 | tilichiki
# Processing Record 36 of Set 8 | oriximina
# Processing Record 37 of Set 8 | paka
# Processing Record 38 of Set 8 | nkhotakota
# Processing Record 39 of Set 8 | murray bridge
# Processing Record 40 of Set 8 | oistins
# Processing Record 41 of Set 8 | vasai
# Processing Record 42 of Set 8 | eyl
# Processing Record 43 of Set 8 | mlalo
# Processing Record 44 of Set 8 | antsohihy
# Processing Record 45 of Set 8 | makat
# Processing Record 46 of Set 8 | povolzhskiy
# Processing Record 47 of Set 8 | fort saint james
# Processing Record 48 of Set 8 | umea
# Processing Record 49 of Set 8 | nalbari
# Processing Record 50 of Set 8 | lelystad
# Processing Record 1 of Set 9 | flinders
# Processing Record 2 of Set 9 | goma
# Processing Record 3 of Set 9 | senno
# Processing Record 4 of Set 9 | gayny
# Processing Record 5 of Set 9 | treinta y tres
# Processing Record 6 of Set 9 | clyde river
# Processing Record 7 of Set 9 | tucuman
# Processing Record 8 of Set 9 | junction city
# Processing Record 9 of Set 9 | marystown
# Processing Record 10 of Set 9 | padang
# Processing Record 11 of Set 9 | itaituba
# Processing Record 12 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 9 | havelock
# Processing Record 15 of Set 9 | sonoita
# Processing Record 16 of Set 9 | ust-maya
# Processing Record 17 of Set 9 | slave lake
# Processing Record 18 of Set 9 | bambous virieux
# Processing Record 19 of Set 9 | kulhudhuffushi
# Processing Record 20 of Set 9 | kungurtug
# Processing Record 21 of Set 9 | jumla
# Processing Record 22 of Set 9 | dunedin
# Processing Record 23 of Set 9 | ishigaki
# Processing Record 24 of Set 9 | sobolevo
# Processing Record 25 of Set 9 | lorengau
# Processing Record 26 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 9 | zhezkazgan
# Processing Record 28 of Set 9 | mae sai
# Processing Record 29 of Set 9 | halifax
# Processing Record 30 of Set 9 | la paz
# Processing Record 31 of Set 9 | san vicente de canete
# Processing Record 32 of Set 9 | aykhal
# Processing Record 33 of Set 9 | puerto leguizamo
# Processing Record 34 of Set 9 | karratha
# Processing Record 35 of Set 9 | hrodna
# Processing Record 36 of Set 9 | strelka
# Processing Record 37 of Set 9 | varna
# Processing Record 38 of Set 9 | kruisfontein
# Processing Record 39 of Set 9 | camacha
# Processing Record 40 of Set 9 | hobyo
# Processing Record 41 of Set 9 | conway
# Processing Record 42 of Set 9 | nortelandia
# Processing Record 43 of Set 9 | kiruna
# Processing Record 44 of Set 9 | rincon
# Processing Record 45 of Set 9 | elizabeth city
# Processing Record 46 of Set 9 | neyshabur
# Processing Record 47 of Set 9 | sorong
# Processing Record 48 of Set 9 | san patricio
# Processing Record 49 of Set 9 | minas
# Processing Record 50 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 1 of Set 10 | monterey
# Processing Record 2 of Set 10 | takoradi
# Processing Record 3 of Set 10 | poum
# Processing Record 4 of Set 10 | xiangxiang
# Processing Record 5 of Set 10 | kazerun
# Processing Record 6 of Set 10 | palauig
# Processing Record 7 of Set 10 | isla vista
# Processing Record 8 of Set 10 | te anau
# Processing Record 9 of Set 10 | moulins
# Processing Record 10 of Set 10 | vila velha
# Processing Record 11 of Set 10 | ostrovnoy
# Processing Record 12 of Set 10 | axim
# Processing Record 13 of Set 10 | uige
# Processing Record 14 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 10 | tarakan
# Processing Record 16 of Set 10 | shanhetun
# Processing Record 17 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 18 of Set 10 | pacific grove
# Processing Record 19 of Set 10 | eregli
# Processing Record 20 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 10 | longyearbyen
# Processing Record 22 of Set 10 | yerbogachen
# Processing Record 23 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 25 of Set 10 | wilmington
# Processing Record 26 of Set 10 | luwuk
# Processing Record 27 of Set 10 | lake charles
# Processing Record 28 of Set 10 | nosy varika
# Processing Record 29 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 10 | novyy urgal
# Processing Record 32 of Set 10 | morant bay
# Processing Record 33 of Set 10 | abha
# Processing Record 34 of Set 10 | college
# Processing Record 35 of Set 10 | clevelandia
# Processing Record 36 of Set 10 | campoverde
# Processing Record 37 of Set 10 | port macquarie
# Processing Record 38 of Set 10 | olafsvik
# Processing Record 39 of Set 10 | voh
# Processing Record 40 of Set 10 | jalu
# Processing Record 41 of Set 10 | san policarpo
# Processing Record 42 of Set 10 | mersing
# Processing Record 43 of Set 10 | baghdad
# Processing Record 44 of Set 10 | honiara
# Processing Record 45 of Set 10 | lososina
# Processing Record 46 of Set 10 | madang
# Processing Record 47 of Set 10 | santiago del estero
# Processing Record 48 of Set 10 | rajmahal
# Processing Record 49 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 10 | longview
# Processing Record 1 of Set 11 | hirara
# Processing Record 2 of Set 11 | kovernino
# Processing Record 3 of Set 11 | kabalo
# Processing Record 4 of Set 11 | arlit
# Processing Record 5 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 11 | neiafu
# Processing Record 7 of Set 11 | bilibino
# Processing Record 8 of Set 11 | south hill
# Processing Record 9 of Set 11 | sturgeon falls
# Processing Record 10 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 11 of Set 11 | matara
# Processing Record 12 of Set 11 | raahe
# Processing Record 13 of Set 11 | petrolandia
# City not found. Skipping...
# Processing Record 14 of Set 11 | novikovo
# Processing Record 15 of Set 11 | half moon bay
# Processing Record 16 of Set 11 | siirt
# Processing Record 17 of Set 11 | tambopata
# Processing Record 18 of Set 11 | nuuk
# Processing Record 19 of Set 11 | newton abbot
# Processing Record 20 of Set 11 | quatre cocos
# Processing Record 21 of Set 11 | comandau
# Processing Record 22 of Set 11 | cabayaoasan
# Processing Record 23 of Set 11 | sarkand
# Processing Record 24 of Set 11 | tigil
# Processing Record 25 of Set 11 | cherskiy
# Processing Record 26 of Set 11 | pitimbu
# Processing Record 27 of Set 11 | coria
# Processing Record 28 of Set 11 | siavonga
# Processing Record 29 of Set 11 | van
# Processing Record 30 of Set 11 | ilo
# Processing Record 31 of Set 11 | atar
# Processing Record 32 of Set 11 | hay river
# Processing Record 33 of Set 11 | visby
# Processing Record 34 of Set 11 | palana
# Processing Record 35 of Set 11 | biak
# Processing Record 36 of Set 11 | cordele
# Processing Record 37 of Set 11 | yazman
# Processing Record 38 of Set 11 | bay roberts
# Processing Record 39 of Set 11 | shchelkun
# Processing Record 40 of Set 11 | noumea
# Processing Record 41 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 11 | warri
# Processing Record 43 of Set 11 | beloha
# Processing Record 44 of Set 11 | paramaribo
# Processing Record 45 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 11 | millinocket
# Processing Record 47 of Set 11 | pokosnoye
# Processing Record 48 of Set 11 | zhangjiakou
# Processing Record 49 of Set 11 | stepanov
# Processing Record 50 of Set 11 | sampit
# Processing Record 1 of Set 12 | alexandria
# Processing Record 2 of Set 12 | nauta
# Processing Record 3 of Set 12 | tlacolula
# Processing Record 4 of Set 12 | bom despacho
# Processing Record 5 of Set 12 | lyaskelya
# Processing Record 6 of Set 12 | aswan
# Processing Record 7 of Set 12 | san isidro
# Processing Record 8 of Set 12 | geraldton
# Processing Record 9 of Set 12 | oleksandrivka
# Processing Record 10 of Set 12 | nemuro
# Processing Record 11 of Set 12 | varkaus
# Processing Record 12 of Set 12 | los banos
# Processing Record 13 of Set 12 | zhigansk
# Processing Record 14 of Set 12 | puri
# Processing Record 15 of Set 12 | tshikapa
# Processing Record 16 of Set 12 | peniche
# Processing Record 17 of Set 12 | honningsvag
# Processing Record 18 of Set 12 | erenhot
# Processing Record 19 of Set 12 | samarai
# Processing Record 20 of Set 12 | fatehabad
# Processing Record 21 of Set 12 | collie
# Processing Record 22 of Set 12 | deputatskiy
# Processing Record 23 of Set 12 | dumas
# Processing Record 24 of Set 12 | caapucu
# Processing Record 25 of Set 12 | taseyevo
# Processing Record 26 of Set 12 | maputo
# Processing Record 27 of Set 12 | kalat
# Processing Record 28 of Set 12 | pires do rio
# Processing Record 29 of Set 12 | jaisalmer
# Processing Record 30 of Set 12 | chicama
# Processing Record 31 of Set 12 | souillac
# Processing Record 32 of Set 12 | kyra
# Processing Record 33 of Set 12 | ixtapa
# Processing Record 34 of Set 12 | moa
# Processing Record 35 of Set 12 | shelburne
# Processing Record 36 of Set 12 | ulaanbaatar
# Processing Record 37 of Set 12 | oxbow
# Processing Record 38 of Set 12 | atkarsk
# Processing Record 39 of Set 12 | marstal
# Processing Record 40 of Set 12 | mopipi
# Processing Record 41 of Set 12 | poole
# Processing Record 42 of Set 12 | salima
# Processing Record 43 of Set 12 | palafrugell
# Processing Record 44 of Set 12 | benguela
# Processing Record 45 of Set 12 | touros
# Processing Record 46 of Set 12 | berbera
# Processing Record 47 of Set 12 | betioky
# Processing Record 48 of Set 12 | lerwick
# Processing Record 49 of Set 12 | broome
# Processing Record 50 of Set 12 | tartagal
# Processing Record 1 of Set 13 | tondano
# Processing Record 2 of Set 13 | great bend
# Processing Record 3 of Set 13 | bugene
# Processing Record 4 of Set 13 | a
# City not found. Skipping...
# Processing Record 5 of Set 13 | shingu
# Processing Record 6 of Set 13 | zavitinsk
# Processing Record 7 of Set 13 | mayumba
# Processing Record 8 of Set 13 | gewane
# Processing Record 9 of Set 13 | sorland
# Processing Record 10 of Set 13 | gouyave
# Processing Record 11 of Set 13 | rio verde de mato grosso
# Processing Record 12 of Set 13 | rypefjord
# Processing Record 13 of Set 13 | blagoveshchenka
# Processing Record 14 of Set 13 | manta
# Processing Record 15 of Set 13 | vestmannaeyjar
# Processing Record 16 of Set 13 | benghazi
# Processing Record 17 of Set 13 | yantal
# Processing Record 18 of Set 13 | maniitsoq
# Processing Record 19 of Set 13 | mount isa
# Processing Record 20 of Set 13 | waipawa
# Processing Record 21 of Set 13 | papar
# Processing Record 22 of Set 13 | porto velho
# Processing Record 23 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 13 | rondonopolis
# Processing Record 25 of Set 13 | ranau
# Processing Record 26 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 13 | mana
# Processing Record 28 of Set 13 | tommot
# Processing Record 29 of Set 13 | uzumlu
# City not found. Skipping...
# Processing Record 30 of Set 13 | samut sakhon
# Processing Record 31 of Set 13 | nanakuli
# Processing Record 32 of Set 13 | miyako
# Processing Record 33 of Set 13 | grafton
# Processing Record 34 of Set 13 | baker city
# Processing Record 35 of Set 13 | plettenberg bay
# Processing Record 36 of Set 13 | aksu
# Processing Record 37 of Set 13 | portland
# Processing Record 38 of Set 13 | anadyr
# Processing Record 39 of Set 13 | redlands
# Processing Record 40 of Set 13 | husavik
# Processing Record 41 of Set 13 | polunochnoye
# Processing Record 42 of Set 13 | marawi
# Processing Record 43 of Set 13 | bam
# Processing Record 44 of Set 13 | kamenskiy
# Processing Record 45 of Set 13 | sarandi
# Processing Record 46 of Set 13 | hudson bay
# Processing Record 47 of Set 13 | juneau
# Processing Record 48 of Set 13 | ilhabela
# Processing Record 49 of Set 13 | niquelandia
# Processing Record 50 of Set 13 | progreso
# Processing Record 1 of Set 14 | garowe
# Processing Record 2 of Set 14 | west lafayette
# Processing Record 3 of Set 14 | renfrew
# Processing Record 4 of Set 14 | strunino
# Processing Record 5 of Set 14 | vila
# Processing Record 6 of Set 14 | ganzhou
# Processing Record 7 of Set 14 | sur
# Processing Record 8 of Set 14 | bekhtery
# Processing Record 9 of Set 14 | san juan
# Processing Record 10 of Set 14 | kikwit
# Processing Record 11 of Set 14 | bimbo
# Processing Record 12 of Set 14 | tolland
# Processing Record 13 of Set 14 | soyo
# Processing Record 14 of Set 14 | jarva-jaani
# Processing Record 15 of Set 14 | mirnyy
# Processing Record 16 of Set 14 | quebec
# Processing Record 17 of Set 14 | tessalit
# Processing Record 18 of Set 14 | luena
# Processing Record 19 of Set 14 | leirvik
# Processing Record 20 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 21 of Set 14 | visnes
# Processing Record 22 of Set 14 | ipixuna
# Processing Record 23 of Set 14 | gizo
# Processing Record 24 of Set 14 | kommunar
# Processing Record 25 of Set 14 | dafeng
# Processing Record 26 of Set 14 | rawson
# Processing Record 27 of Set 14 | jinka
# Processing Record 28 of Set 14 | qasigiannguit
# Processing Record 29 of Set 14 | hervey bay
# Processing Record 30 of Set 14 | totness
# Processing Record 31 of Set 14 | puerto colombia
# Processing Record 32 of Set 14 | campiglia marittima
# Processing Record 33 of Set 14 | akhtubinsk
# Processing Record 34 of Set 14 | solnechnyy
# Processing Record 35 of Set 14 | paamiut
# Processing Record 36 of Set 14 | lata
# Processing Record 37 of Set 14 | xining
# Processing Record 38 of Set 14 | okahandja
# Processing Record 39 of Set 14 | whitianga
# Processing Record 40 of Set 14 | okha
# Processing Record 41 of Set 14 | aksarka
# Processing Record 42 of Set 14 | farrukhnagar
# Processing Record 43 of Set 14 | ekimchan
# Processing Record 44 of Set 14 | springdale
# Processing Record 45 of Set 14 | bartica
# Processing Record 46 of Set 14 | teguldet
# Processing Record 47 of Set 14 | saint-georges
# Processing Record 48 of Set 14 | tabou
# Processing Record 49 of Set 14 | choix
# Processing Record 50 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 1 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 15 | leninskoye
# Processing Record 3 of Set 15 | djibo
# Processing Record 4 of Set 15 | northam
# Processing Record 5 of Set 15 | channel-port aux basques
# Processing Record 6 of Set 15 | oranjemund
# Processing Record 7 of Set 15 | guaratinga
# Processing Record 8 of Set 15 | nicoya
# Processing Record 9 of Set 15 | mahon
# Processing Record 10 of Set 15 | tevaitoa
# Processing Record 11 of Set 15 | dalvik
# Processing Record 12 of Set 15 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 13 of Set 15 | santa rosa
# Processing Record 14 of Set 15 | luanda
# Processing Record 15 of Set 15 | tazovskiy
# Processing Record 16 of Set 15 | mahibadhoo
# Processing Record 17 of Set 15 | nexo
# Processing Record 18 of Set 15 | bondo
# Processing Record 19 of Set 15 | atsiki
# City not found. Skipping...
# Processing Record 20 of Set 15 | worthington
# Processing Record 21 of Set 15 | altamont
# Processing Record 22 of Set 15 | faya
# Processing Record 23 of Set 15 | champerico
# Processing Record 24 of Set 15 | yukamenskoye
# Processing Record 25 of Set 15 | ust-omchug
# Processing Record 26 of Set 15 | mehamn
# Processing Record 27 of Set 15 | rawah
# Processing Record 28 of Set 15 | villamontes
# Processing Record 29 of Set 15 | cervo
# Processing Record 30 of Set 15 | xam nua
# Processing Record 31 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 15 | angoche
# Processing Record 33 of Set 15 | kindu
# Processing Record 34 of Set 15 | bulgan
# Processing Record 35 of Set 15 | kiama
# Processing Record 36 of Set 15 | pital
# Processing Record 37 of Set 15 | uarini
# Processing Record 38 of Set 15 | pascagoula
# Processing Record 39 of Set 15 | okhotsk
# Processing Record 40 of Set 15 | egvekinot
# Processing Record 41 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 15 | mayo
# Processing Record 43 of Set 15 | beckley
# Processing Record 44 of Set 15 | karasburg
# Processing Record 45 of Set 15 | cockburn town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 678

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0      Rikitea -23.1203 -134.9692     74.82          few clouds        73
# 1       Eravur   7.7733   81.6095     76.50     overcast clouds        85
# 2  Belaya Gora  68.5333  146.4167    -46.77    scattered clouds        92
# 3       Cuamba -14.8031   36.5372     71.76          light rain        85
# 4     Thompson  55.7435  -97.8558    -27.24          few clouds        75
# 5     Araouane  18.9048   -3.5265     83.84       broken clouds        13
# 6        Tiksi  71.6872  128.8694    -23.80       broken clouds       100
# 7       Castro -24.7911  -50.0119     75.43    scattered clouds        77
# 8        Kashi  39.4547   75.9797     29.41       broken clouds        34
# 9       Atuona  -9.8000 -139.0333     77.05          light rain        77
#
#    Cloudiness  Wind Speed Country
# 0          13       14.90      PF
# 1         100       11.39      LK
# 2          36        3.02      RU
# 3          92        2.42      MZ
# 4          20        5.75      CA
# 5          81        5.93      ML
# 6          82        4.27      RU
# 7          47        8.93      BR
# 8          63        2.24      CN
# 9          46       14.27      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]


# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rikitea      PF -23.1203 -134.9692     74.82        73          13
# 1       Eravur      LK   7.7733   81.6095     76.50        85         100
# 2  Belaya Gora      RU  68.5333  146.4167    -46.77        92          36
# 3       Cuamba      MZ -14.8031   36.5372     71.76        85          92
# 4     Thompson      CA  55.7435  -97.8558    -27.24        75          20
# 5     Araouane      ML  18.9048   -3.5265     83.84        13          81
# 6        Tiksi      RU  71.6872  128.8694    -23.80       100          82
# 7       Castro      BR -24.7911  -50.0119     75.43        77          47
# 8        Kashi      CN  39.4547   75.9797     29.41        34          63
# 9       Atuona      PF  -9.8000 -139.0333     77.05        77          46
#
#    Wind Speed Current Description
# 0       14.90          few clouds
# 1       11.39     overcast clouds
# 2        3.02    scattered clouds
# 3        2.42          light rain
# 4        5.75          few clouds
# 5        5.93       broken clouds
# 6        4.27       broken clouds
# 7        8.93    scattered clouds
# 8        2.24       broken clouds
# 9       14.27          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
